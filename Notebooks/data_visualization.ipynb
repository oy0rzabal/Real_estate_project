# %%
#Importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
      #Raiz, Carpetaprincipal, Carpeta
renta = 'Data_renta.xlsx'
venta = 'Data_venta.xlsx'

renta = pd.read_excel(renta)
venta = pd.read_excel(venta)

renta = pd.DataFrame(renta)
venta = pd.DataFrame(venta)

# %% [markdown]
# #Preguntas de negocios
# ¿Cuanto es el total de los m2 de cada zona?
#
# ¿Cual es el m2 mas alto por cada zona?
#
# ¿Cual es el m2 promedio a rentar por zona?
#
# +--------------------------------------------+
#
# ¿Cual es la Oficina mas cara para rentar?
#
# ¿Cual es la Oficina en promedio a rentar?
#
# ¿Cual es la Oficina menos caras en rentar?
#
# +---------------------------------------------+
#
# ¿Cual es la Oficina mas cara para venta?
#
# ¿Cual es la Oficina en promedio a venta?
#
# ¿Cual es la Oficina menos caras en venta?
#
# +---------------------------------------------+
#
# Resultado total de los banos que contienen por zona?
#
# Cuantas oficinas tiene o contiene menos banos?
#
# cuantas oficinas contiene mas banos?
#
# Caul es el promedio de banos en total de las Oficina?
#
# +---------------------------------------------+

# %% [markdown]
# #Resolviendo las preguntas de negocio con Renta

# %%
#preguntas sobre los m2 de cada oficina por zona

# %%
¿Cuanto es el total de los m2 de cada zona?
# Out:
# Object `zona` not found.

# %%
renta['Colonia'].head(1)
# Out:
# 0    Alaminos
# Name: Colonia, dtype: object

# %%
venta['Colonia'].head(1)
# Out:
# 0    Alaminos
# Name: Colonia, dtype: object

# %%
x = renta['Colonia']
y = renta['m2']

plt.scatter(x, y)
plt.show()

# %%
¿Cual es el m2 mas alto por cada zona?
# Out:
# Object `zona` not found.

# %%
¿Cual es el m2 promedio a rentar por zona?
# Out:
# Object `zona` not found.

# %%
#Preguntas sobre los precios de venta de las oficinas

# %%
¿Cual es la Oficina mas cara para venta?

# %%
¿Cual es la Oficina en promedio a venta?

# %%
¿Cual es la Oficina menos caras en venta?

# %%
#Preguntas sobre los precios de renta  de las oficinas

# %%
¿Cual es la Oficina mas cara para rentar?

¿Cual es la Oficina en promedio a rentar?

¿Cual es la Oficina menos caras en rentar?
# Out:
# Object `rentar` not found.
# Object `rentar` not found.
# Object `rentar` not found.

# %%
#Preguntas relacionadas de los banos por la zona por cada oficina

# %%
Resultado total de los banos que contienen por zona?

Cuantas oficinas tiene o contiene menos banos?

cuantas oficinas contiene mas banos?

Caul es el promedio de banos en total de las Oficina?
